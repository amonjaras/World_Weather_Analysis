# %% [markdown]
# # Deliverable 1
#
# Generate a set of 2,000 random latitudes and longitudes, retrive the nearest city,
# and perform an APU call with the OpenWeatherMap. In addition to the weather data,
# retreive the current weather description for each city. Then, create a new DataFrame
# containing the updated weather data.

# %%
# Import the dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy

# %%
# Create a new set of 2000 random latitudes and longitudes
lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -90, high = 90, size = 2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %%
# Create a list to hold the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Build query URL and request your results in Celsius
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5) # Changed to 5 seconds to reduce waiting time

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title()
                          ,"Country": city_country
                          ,"Lat": city_lat
                          ,"Lng": city_lng
                          ,"Current Description": city_description
                          ,"Max Temp": city_max_temp
                          ,"Humidity": city_humidity
                          ,"Cloudiness": city_clouds
                          ,"Wind Speed": city_wind})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kostomuksha
# Processing Record 2 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 1 | victoria
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | gander
# Processing Record 6 of Set 1 | serpa
# Processing Record 7 of Set 1 | arraial do cabo
# Processing Record 8 of Set 1 | luderitz
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | henties bay
# Processing Record 11 of Set 1 | olean
# Processing Record 12 of Set 1 | saint-pierre
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | ambovombe
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | vesele
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | qaanaaq
# Processing Record 19 of Set 1 | bodden town
# Processing Record 20 of Set 1 | la sarre
# Processing Record 21 of Set 1 | tukrah
# Processing Record 22 of Set 1 | havre-saint-pierre
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | mutsamudu
# City not found. Skipping...
# Processing Record 26 of Set 1 | pereslavl-zalesskiy
# Processing Record 27 of Set 1 | upernavik
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | parfino
# Processing Record 30 of Set 1 | ribeira grande
# Processing Record 31 of Set 1 | buraydah
# Processing Record 32 of Set 1 | quatre cocos
# Processing Record 33 of Set 1 | mehran
# Processing Record 34 of Set 1 | mutare
# Processing Record 35 of Set 1 | tessaoua
# Processing Record 36 of Set 1 | cap malheureux
# Processing Record 37 of Set 1 | mahaicony
# City not found. Skipping...
# Processing Record 38 of Set 1 | terekli-mekteb
# Processing Record 39 of Set 1 | fuerte olimpo
# Processing Record 40 of Set 1 | santa rosa
# Processing Record 41 of Set 1 | argentan
# Processing Record 42 of Set 1 | sagua de tanamo
# Processing Record 43 of Set 1 | pallisa
# Processing Record 44 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | vila velha
# Processing Record 47 of Set 1 | maceio
# Processing Record 48 of Set 1 | saint pete beach
# Processing Record 49 of Set 1 | carmen de carupa
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | nara
# Processing Record 2 of Set 2 | mana
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 2 | lincoln
# Processing Record 6 of Set 2 | los llanos de aridane
# Processing Record 7 of Set 2 | angoche
# Processing Record 8 of Set 2 | ostrovnoy
# Processing Record 9 of Set 2 | fostoria
# Processing Record 10 of Set 2 | shchelyayur
# City not found. Skipping...
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | hobyo
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | paamiut
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | port blair
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | sabha
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | kavaratti
# Processing Record 21 of Set 2 | maxixe
# Processing Record 22 of Set 2 | ilulissat
# Processing Record 23 of Set 2 | athol
# Processing Record 24 of Set 2 | nioro
# Processing Record 25 of Set 2 | salta
# Processing Record 26 of Set 2 | oranjemund
# Processing Record 27 of Set 2 | bulawayo
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | talnakh
# Processing Record 30 of Set 2 | somerset
# Processing Record 31 of Set 2 | nanortalik
# Processing Record 32 of Set 2 | chapais
# Processing Record 33 of Set 2 | lucea
# Processing Record 34 of Set 2 | husavik
# Processing Record 35 of Set 2 | nuuk
# Processing Record 36 of Set 2 | araxa
# Processing Record 37 of Set 2 | longyearbyen
# Processing Record 38 of Set 2 | pesochenskiy
# Processing Record 39 of Set 2 | saint-joseph
# Processing Record 40 of Set 2 | bengkulu
# Processing Record 41 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | mar del plata
# Processing Record 44 of Set 2 | tasiilaq
# Processing Record 45 of Set 2 | bosobolo
# Processing Record 46 of Set 2 | aripuana
# Processing Record 47 of Set 2 | taoudenni
# Processing Record 48 of Set 2 | salalah
# Processing Record 49 of Set 2 | clyde river
# Processing Record 50 of Set 2 | veshenskaya
# Processing Record 1 of Set 3 | karachi
# Processing Record 2 of Set 3 | manitouwadge
# Processing Record 3 of Set 3 | ambilobe
# Processing Record 4 of Set 3 | clarence town
# Processing Record 5 of Set 3 | elizabeth city
# Processing Record 6 of Set 3 | coihaique
# Processing Record 7 of Set 3 | necochea
# Processing Record 8 of Set 3 | sao filipe
# Processing Record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 3 | vestmannaeyjar
# Processing Record 11 of Set 3 | bharatpur
# Processing Record 12 of Set 3 | ranavav
# Processing Record 13 of Set 3 | olinda
# Processing Record 14 of Set 3 | san carlos de bariloche
# Processing Record 15 of Set 3 | padang
# Processing Record 16 of Set 3 | damietta
# Processing Record 17 of Set 3 | vardo
# Processing Record 18 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 3 | mitsamiouli
# Processing Record 20 of Set 3 | sechura
# Processing Record 21 of Set 3 | bathsheba
# Processing Record 22 of Set 3 | pitimbu
# Processing Record 23 of Set 3 | marienburg
# Processing Record 24 of Set 3 | hit
# Processing Record 25 of Set 3 | usinsk
# Processing Record 26 of Set 3 | vila franca do campo
# Processing Record 27 of Set 3 | rawson
# Processing Record 28 of Set 3 | saldanha
# Processing Record 29 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 3 | olafsvik
# Processing Record 31 of Set 3 | monrovia
# Processing Record 32 of Set 3 | chingirlau
# Processing Record 33 of Set 3 | namibe
# Processing Record 34 of Set 3 | goderich
# Processing Record 35 of Set 3 | leh
# Processing Record 36 of Set 3 | mahebourg
# Processing Record 37 of Set 3 | buriti alegre
# Processing Record 38 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 3 | kansanshi
# Processing Record 40 of Set 3 | coquimbo
# Processing Record 41 of Set 3 | iqaluit
# Processing Record 42 of Set 3 | grand gaube
# Processing Record 43 of Set 3 | ilebo
# Processing Record 44 of Set 3 | hamilton
# Processing Record 45 of Set 3 | planeta rica
# Processing Record 46 of Set 3 | jampur
# Processing Record 47 of Set 3 | alamor
# Processing Record 48 of Set 3 | chuy
# Processing Record 49 of Set 3 | lodja
# Processing Record 50 of Set 3 | presidente medici
# Processing Record 1 of Set 4 | rocha
# Processing Record 2 of Set 4 | punta arenas
# Processing Record 3 of Set 4 | contai
# Processing Record 4 of Set 4 | tessalit
# Processing Record 5 of Set 4 | virginia beach
# Processing Record 6 of Set 4 | asfi
# Processing Record 7 of Set 4 | constitucion
# Processing Record 8 of Set 4 | tagab
# Processing Record 9 of Set 4 | geraldton
# Processing Record 10 of Set 4 | kollam
# Processing Record 11 of Set 4 | alta floresta
# Processing Record 12 of Set 4 | faya
# Processing Record 13 of Set 4 | plettenberg bay
# Processing Record 14 of Set 4 | saint anthony
# Processing Record 15 of Set 4 | cozumel
# Processing Record 16 of Set 4 | itamarandiba
# Processing Record 17 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 4 | rorvik
# Processing Record 19 of Set 4 | turukhansk
# Processing Record 20 of Set 4 | san rafael
# Processing Record 21 of Set 4 | beziers
# Processing Record 22 of Set 4 | siniscola
# Processing Record 23 of Set 4 | senador pompeu
# Processing Record 24 of Set 4 | uglich
# Processing Record 25 of Set 4 | codrington
# Processing Record 26 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 27 of Set 4 | laguna
# Processing Record 28 of Set 4 | richards bay
# Processing Record 29 of Set 4 | cockburn town
# Processing Record 30 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 31 of Set 4 | cidreira
# Processing Record 32 of Set 4 | ndouci
# City not found. Skipping...
# Processing Record 33 of Set 4 | bubaque
# Processing Record 34 of Set 4 | micheweni
# Processing Record 35 of Set 4 | gagarin
# Processing Record 36 of Set 4 | corinto
# Processing Record 37 of Set 4 | manturovo
# Processing Record 38 of Set 4 | bud
# Processing Record 39 of Set 4 | vila do maio
# Processing Record 40 of Set 4 | sovetskiy
# Processing Record 41 of Set 4 | terlicko
# City not found. Skipping...
# Processing Record 42 of Set 4 | banda aceh
# Processing Record 43 of Set 4 | the valley
# Processing Record 44 of Set 4 | sakakah
# Processing Record 45 of Set 4 | baglung
# Processing Record 46 of Set 4 | uroteppa
# City not found. Skipping...
# Processing Record 47 of Set 4 | sao caetano de odivelas
# Processing Record 48 of Set 4 | akonolinga
# Processing Record 49 of Set 4 | guekedou
# City not found. Skipping...
# Processing Record 50 of Set 4 | sitrah
# Processing Record 1 of Set 5 | lokosovo
# Processing Record 2 of Set 5 | changji
# Processing Record 3 of Set 5 | amapa
# Processing Record 4 of Set 5 | gudari
# Processing Record 5 of Set 5 | opuwo
# Processing Record 6 of Set 5 | honningsvag
# Processing Record 7 of Set 5 | narsaq
# Processing Record 8 of Set 5 | san andres
# Processing Record 9 of Set 5 | vallenar
# Processing Record 10 of Set 5 | madison heights
# Processing Record 11 of Set 5 | viedma
# Processing Record 12 of Set 5 | costinesti
# Processing Record 13 of Set 5 | tambopata
# Processing Record 14 of Set 5 | arlit
# Processing Record 15 of Set 5 | gat
# Processing Record 16 of Set 5 | cariati
# Processing Record 17 of Set 5 | pangody
# Processing Record 18 of Set 5 | savannah bight
# Processing Record 19 of Set 5 | toamasina
# Processing Record 20 of Set 5 | plouzane
# Processing Record 21 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 22 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 23 of Set 5 | kouango
# Processing Record 24 of Set 5 | hargeysa
# Processing Record 25 of Set 5 | dromolaxia
# Processing Record 26 of Set 5 | ponta delgada
# Processing Record 27 of Set 5 | lubao
# Processing Record 28 of Set 5 | praia
# Processing Record 29 of Set 5 | chernukha
# Processing Record 30 of Set 5 | uyovu
# Processing Record 31 of Set 5 | akkermanovka
# Processing Record 32 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 33 of Set 5 | suluova
# Processing Record 34 of Set 5 | oktyabrskoye
# Processing Record 35 of Set 5 | malatya
# Processing Record 36 of Set 5 | wamba
# Processing Record 37 of Set 5 | castro
# Processing Record 38 of Set 5 | moussoro
# Processing Record 39 of Set 5 | san juan
# Processing Record 40 of Set 5 | kuytun
# Processing Record 41 of Set 5 | sinnamary
# Processing Record 42 of Set 5 | bonthe
# Processing Record 43 of Set 5 | grao mogol
# Processing Record 44 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 5 | caravelas
# Processing Record 46 of Set 5 | keskin
# Processing Record 47 of Set 5 | aiani
# Processing Record 48 of Set 5 | bajo baudo
# City not found. Skipping...
# Processing Record 49 of Set 5 | cervo
# Processing Record 50 of Set 5 | monki
# Processing Record 1 of Set 6 | jasrana
# Processing Record 2 of Set 6 | luba
# Processing Record 3 of Set 6 | kamenka
# Processing Record 4 of Set 6 | bilma
# Processing Record 5 of Set 6 | burgos
# Processing Record 6 of Set 6 | pustoshka
# Processing Record 7 of Set 6 | chany
# Processing Record 8 of Set 6 | qaqortoq
# Processing Record 9 of Set 6 | akureyri
# Processing Record 10 of Set 6 | teguldet
# Processing Record 11 of Set 6 | trofors
# Processing Record 12 of Set 6 | sargur
# Processing Record 13 of Set 6 | inongo
# Processing Record 14 of Set 6 | lytkarino
# Processing Record 15 of Set 6 | awbari
# Processing Record 16 of Set 6 | odweyne
# Processing Record 17 of Set 6 | misratah
# Processing Record 18 of Set 6 | karaidel
# Processing Record 19 of Set 6 | bambous virieux
# Processing Record 20 of Set 6 | sisimiut
# Processing Record 21 of Set 6 | garowe
# Processing Record 22 of Set 6 | ponta do sol
# Processing Record 23 of Set 6 | quelimane
# Processing Record 24 of Set 6 | hofn
# Processing Record 25 of Set 6 | srisailam
# Processing Record 26 of Set 6 | klaksvik
# Processing Record 27 of Set 6 | cayenne
# Processing Record 28 of Set 6 | saint-georges
# Processing Record 29 of Set 6 | borisoglebskiy
# Processing Record 30 of Set 6 | rio gallegos
# Processing Record 31 of Set 6 | fethiye
# Processing Record 32 of Set 6 | manta
# Processing Record 33 of Set 6 | emba
# Processing Record 34 of Set 6 | pyaozerskiy
# Processing Record 35 of Set 6 | svetlyy
# Processing Record 36 of Set 6 | mahanoro
# Processing Record 37 of Set 6 | maunabo
# Processing Record 38 of Set 6 | san cristobal
# Processing Record 39 of Set 6 | mmabatho
# Processing Record 40 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 6 | kongolo
# Processing Record 42 of Set 6 | yar-sale
# Processing Record 43 of Set 6 | ust-koksa
# Processing Record 44 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 45 of Set 6 | urubicha
# Processing Record 46 of Set 6 | gazli
# Processing Record 47 of Set 6 | djambala
# Processing Record 48 of Set 6 | tazmalt
# Processing Record 49 of Set 6 | mosquera
# Processing Record 50 of Set 6 | maniitsoq
# Processing Record 1 of Set 7 | rio grande
# Processing Record 2 of Set 7 | moose factory
# Processing Record 3 of Set 7 | nouakchott
# Processing Record 4 of Set 7 | porto novo
# Processing Record 5 of Set 7 | adrar
# Processing Record 6 of Set 7 | gremyachinsk
# Processing Record 7 of Set 7 | berlevag
# Processing Record 8 of Set 7 | ahvaz
# Processing Record 9 of Set 7 | nantucket
# Processing Record 10 of Set 7 | lashma
# Processing Record 11 of Set 7 | tiznit
# Processing Record 12 of Set 7 | hualmay
# Processing Record 13 of Set 7 | thompson
# Processing Record 14 of Set 7 | calbuco
# Processing Record 15 of Set 7 | werda
# Processing Record 16 of Set 7 | kuusamo
# Processing Record 17 of Set 7 | syracuse
# Processing Record 18 of Set 7 | torbat-e jam
# Processing Record 19 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 7 | kiruna
# Processing Record 21 of Set 7 | carnarvon
# Processing Record 22 of Set 7 | tambura
# Processing Record 23 of Set 7 | taywarah
# Processing Record 24 of Set 7 | urumqi
# Processing Record 25 of Set 7 | kembe
# Processing Record 26 of Set 7 | giehun
# Processing Record 27 of Set 7 | ust-tsilma
# Processing Record 28 of Set 7 | roald
# Processing Record 29 of Set 7 | tucuman
# Processing Record 30 of Set 7 | paracuru
# Processing Record 31 of Set 7 | pires do rio
# Processing Record 32 of Set 7 | jalu
# Processing Record 33 of Set 7 | ancud
# Processing Record 34 of Set 7 | brae
# Processing Record 35 of Set 7 | batsfjord
# Processing Record 36 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 7 | khalkhal
# Processing Record 38 of Set 7 | samarina
# Processing Record 39 of Set 7 | harbour breton
# Processing Record 40 of Set 7 | grande-riviere
# City not found. Skipping...
# Processing Record 41 of Set 7 | dhone
# Processing Record 42 of Set 7 | belaguntha
# Processing Record 43 of Set 7 | ahtopol
# Processing Record 44 of Set 7 | tabou
# Processing Record 45 of Set 7 | touros
# Processing Record 46 of Set 7 | imperia
# Processing Record 47 of Set 7 | korla
# Processing Record 48 of Set 7 | nizhniy odes
# Processing Record 49 of Set 7 | choszczno
# Processing Record 50 of Set 7 | marsh harbour
# Processing Record 1 of Set 8 | penzance
# Processing Record 2 of Set 8 | natal
# Processing Record 3 of Set 8 | burica
# City not found. Skipping...
# Processing Record 4 of Set 8 | mayumba
# Processing Record 5 of Set 8 | bandarbeyla
# Processing Record 6 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 8 | iskateley
# Processing Record 8 of Set 8 | eydhafushi
# Processing Record 9 of Set 8 | bicester
# Processing Record 10 of Set 8 | kensington
# Processing Record 11 of Set 8 | lethem
# Processing Record 12 of Set 8 | bani
# Processing Record 13 of Set 8 | gilbues
# Processing Record 14 of Set 8 | gurlan
# Processing Record 15 of Set 8 | mykolayiv
# Processing Record 16 of Set 8 | safaga
# Processing Record 17 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 18 of Set 8 | porto murtinho
# Processing Record 19 of Set 8 | camacha
# Processing Record 20 of Set 8 | gamba
# Processing Record 21 of Set 8 | artvin
# Processing Record 22 of Set 8 | bereda
# Processing Record 23 of Set 8 | kudahuvadhoo
# Processing Record 24 of Set 8 | camapua
# Processing Record 25 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 26 of Set 8 | malm
# Processing Record 27 of Set 8 | mehamn
# Processing Record 28 of Set 8 | yendi
# Processing Record 29 of Set 8 | muli
# Processing Record 30 of Set 8 | bolokhovo
# Processing Record 31 of Set 8 | inhambane
# Processing Record 32 of Set 8 | fonte boa
# Processing Record 33 of Set 8 | saint george
# Processing Record 34 of Set 8 | nadym
# Processing Record 35 of Set 8 | havelock
# Processing Record 36 of Set 8 | sorkjosen
# Processing Record 37 of Set 8 | havoysund
# Processing Record 38 of Set 8 | komsomolets
# Processing Record 39 of Set 8 | zaozerne
# Processing Record 40 of Set 8 | omboue
# Processing Record 41 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 42 of Set 8 | kargopol
# Processing Record 43 of Set 8 | okrika
# Processing Record 44 of Set 8 | marawi
# Processing Record 45 of Set 8 | makueni
# Processing Record 46 of Set 8 | rayagada
# Processing Record 47 of Set 8 | pachino
# Processing Record 48 of Set 8 | sambava
# Processing Record 49 of Set 8 | charkhi dadri
# Processing Record 50 of Set 8 | madimba
# Processing Record 1 of Set 9 | despotovac
# Processing Record 2 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 3 of Set 9 | domoni
# Processing Record 4 of Set 9 | forest hills
# Processing Record 5 of Set 9 | jevargi
# Processing Record 6 of Set 9 | dingle
# Processing Record 7 of Set 9 | severnoye
# Processing Record 8 of Set 9 | fatehpur
# Processing Record 9 of Set 9 | khorixas
# Processing Record 10 of Set 9 | frohnleiten
# Processing Record 11 of Set 9 | axim
# Processing Record 12 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 9 | vadso
# Processing Record 14 of Set 9 | bardiyah
# Processing Record 15 of Set 9 | cabedelo
# Processing Record 16 of Set 9 | ciudad bolivar
# Processing Record 17 of Set 9 | askino
# Processing Record 18 of Set 9 | kruisfontein
# Processing Record 19 of Set 9 | bossangoa
# Processing Record 20 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 9 | tacuarembo
# Processing Record 22 of Set 9 | malindi
# Processing Record 23 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 24 of Set 9 | manacapuru
# Processing Record 25 of Set 9 | talas
# Processing Record 26 of Set 9 | matameye
# City not found. Skipping...
# Processing Record 27 of Set 9 | visnes
# Processing Record 28 of Set 9 | viransehir
# Processing Record 29 of Set 9 | los andes
# Processing Record 30 of Set 9 | makrana
# Processing Record 31 of Set 9 | caxito
# Processing Record 32 of Set 9 | paramonga
# Processing Record 33 of Set 9 | afmadu
# City not found. Skipping...
# Processing Record 34 of Set 9 | pangnirtung
# Processing Record 35 of Set 9 | pedro juan caballero
# Processing Record 36 of Set 9 | okakarara
# Processing Record 37 of Set 9 | ipanema
# Processing Record 38 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 9 | lisov
# Processing Record 40 of Set 9 | alto paraguai
# Processing Record 41 of Set 9 | carnot
# Processing Record 42 of Set 9 | rosendal
# Processing Record 43 of Set 9 | sao joao da barra
# Processing Record 44 of Set 9 | estelle
# Processing Record 45 of Set 9 | ileza
# Processing Record 46 of Set 9 | tres arroyos
# Processing Record 47 of Set 9 | belmonte
# Processing Record 48 of Set 9 | porto uniao
# Processing Record 49 of Set 9 | peachtree city
# Processing Record 50 of Set 9 | montepuez
# Processing Record 1 of Set 10 | junin
# Processing Record 2 of Set 10 | morant bay
# Processing Record 3 of Set 10 | esfarayen
# Processing Record 4 of Set 10 | liberec
# Processing Record 5 of Set 10 | bihar
# Processing Record 6 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 10 | port-gentil
# Processing Record 8 of Set 10 | sur
# Processing Record 9 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 10 of Set 10 | qeshm
# Processing Record 11 of Set 10 | marovoay
# Processing Record 12 of Set 10 | sayyan
# Processing Record 13 of Set 10 | burgeo
# Processing Record 14 of Set 10 | aquidaba
# Processing Record 15 of Set 10 | pastavy
# Processing Record 16 of Set 10 | altamira
# Processing Record 17 of Set 10 | marabba
# Processing Record 18 of Set 10 | valera
# Processing Record 19 of Set 10 | medina
# Processing Record 20 of Set 10 | sumbe
# Processing Record 21 of Set 10 | mogadishu
# Processing Record 22 of Set 10 | walvis bay
# Processing Record 23 of Set 10 | marsaxlokk
# Processing Record 24 of Set 10 | solothurn
# Processing Record 25 of Set 10 | dullewala
# Processing Record 26 of Set 10 | mecca
# Processing Record 27 of Set 10 | henderson
# Processing Record 28 of Set 10 | galle
# Processing Record 29 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 30 of Set 10 | abu samrah
# Processing Record 31 of Set 10 | jacareacanga
# Processing Record 32 of Set 10 | punahana
# Processing Record 33 of Set 10 | breves
# Processing Record 34 of Set 10 | krasnyy kurgan
# Processing Record 35 of Set 10 | carballo
# Processing Record 36 of Set 10 | okandja
# City not found. Skipping...
# Processing Record 37 of Set 10 | yenagoa
# Processing Record 38 of Set 10 | medfield
# Processing Record 39 of Set 10 | concepcion del uruguay
# Processing Record 40 of Set 10 | aligudarz
# Processing Record 41 of Set 10 | la romana
# Processing Record 42 of Set 10 | gouyave
# Processing Record 43 of Set 10 | gilgit
# Processing Record 44 of Set 10 | muros
# Processing Record 45 of Set 10 | swellendam
# Processing Record 46 of Set 10 | bonavista
# Processing Record 47 of Set 10 | boden
# Processing Record 48 of Set 10 | gouloure
# Processing Record 49 of Set 10 | huarmey
# Processing Record 50 of Set 10 | campos do jordao
# Processing Record 1 of Set 11 | alta gracia
# Processing Record 2 of Set 11 | sol-iletsk
# Processing Record 3 of Set 11 | golyshmanovo
# Processing Record 4 of Set 11 | marzuq
# Processing Record 5 of Set 11 | road town
# Processing Record 6 of Set 11 | comodoro rivadavia
# Processing Record 7 of Set 11 | nsanje
# Processing Record 8 of Set 11 | forio
# Processing Record 9 of Set 11 | mandera
# Processing Record 10 of Set 11 | sept-iles
# Processing Record 11 of Set 11 | eyrarbakki
# Processing Record 12 of Set 11 | boueni
# Processing Record 13 of Set 11 | la rioja
# Processing Record 14 of Set 11 | zabolottya
# City not found. Skipping...
# Processing Record 15 of Set 11 | chicama
# Processing Record 16 of Set 11 | curillo
# Processing Record 17 of Set 11 | landau
# Processing Record 18 of Set 11 | kataysk
# Processing Record 19 of Set 11 | les cayes
# Processing Record 20 of Set 11 | humberto de campos
# Processing Record 21 of Set 11 | itaituba
# Processing Record 22 of Set 11 | derzhavinsk
# Processing Record 23 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 11 | bosaso
# Processing Record 25 of Set 11 | hemsedal
# Processing Record 26 of Set 11 | hambantota
# Processing Record 27 of Set 11 | kalmunai
# Processing Record 28 of Set 11 | sarnen
# Processing Record 29 of Set 11 | rudbar
# Processing Record 30 of Set 11 | pagondas
# City not found. Skipping...
# Processing Record 31 of Set 11 | bokoro
# Processing Record 32 of Set 11 | dubai
# Processing Record 33 of Set 11 | harper
# Processing Record 34 of Set 11 | beyneu
# Processing Record 35 of Set 11 | mutis
# Processing Record 36 of Set 11 | guisa
# Processing Record 37 of Set 11 | mwinilunga
# Processing Record 38 of Set 11 | boende
# Processing Record 39 of Set 11 | yanam
# Processing Record 40 of Set 11 | dir
# Processing Record 41 of Set 11 | upata
# Processing Record 42 of Set 11 | bullingen
# City not found. Skipping...
# Processing Record 43 of Set 11 | ribas do rio pardo
# Processing Record 44 of Set 11 | inyonga
# Processing Record 45 of Set 11 | alexandria
# Processing Record 46 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 11 | boa vista
# Processing Record 48 of Set 11 | staropesterevo
# Processing Record 49 of Set 11 | torrelavega
# Processing Record 50 of Set 11 | krasnoselkup
# Processing Record 1 of Set 12 | diego de almagro
# Processing Record 2 of Set 12 | rabo de peixe
# Processing Record 3 of Set 12 | salinas
# Processing Record 4 of Set 12 | talara
# Processing Record 5 of Set 12 | cherepovets
# Processing Record 6 of Set 12 | ngong
# Processing Record 7 of Set 12 | gloucester
# Processing Record 8 of Set 12 | somerset east
# Processing Record 9 of Set 12 | praia da vitoria
# Processing Record 10 of Set 12 | alegre
# Processing Record 11 of Set 12 | high rock
# Processing Record 12 of Set 12 | bolobo
# Processing Record 13 of Set 12 | allingabro
# Processing Record 14 of Set 12 | scanteiesti
# City not found. Skipping...
# Processing Record 15 of Set 12 | palmares do sul
# Processing Record 16 of Set 12 | nsunga
# Processing Record 17 of Set 12 | pisco
# Processing Record 18 of Set 12 | nokaneng
# Processing Record 19 of Set 12 | souillac
# Processing Record 20 of Set 12 | ugoofaaru
# Processing Record 21 of Set 12 | porto velho
# Processing Record 22 of Set 12 | tiruvottiyur
# City not found. Skipping...
# Processing Record 23 of Set 12 | great yarmouth
# Processing Record 24 of Set 12 | pimentel
# Processing Record 25 of Set 12 | morondava
# Processing Record 26 of Set 12 | pascagoula
# Processing Record 27 of Set 12 | doka
# Processing Record 28 of Set 12 | peniche
# Processing Record 29 of Set 12 | matara
# Processing Record 30 of Set 12 | bilopillya
# Processing Record 31 of Set 12 | repnoye
# Processing Record 32 of Set 12 | paita
# Processing Record 33 of Set 12 | tema
# Processing Record 34 of Set 12 | arkhangelsk
# Processing Record 35 of Set 12 | le passage
# Processing Record 36 of Set 12 | malkapur
# Processing Record 37 of Set 12 | umarkot
# Processing Record 38 of Set 12 | terni
# Processing Record 39 of Set 12 | tazovskiy
# Processing Record 40 of Set 12 | punganuru
# Processing Record 41 of Set 12 | koping
# Processing Record 42 of Set 12 | general roca
# Processing Record 43 of Set 12 | purpe
# Processing Record 44 of Set 12 | benguela
# Processing Record 45 of Set 12 | kubanskiy
# Processing Record 46 of Set 12 | calabozo
# Processing Record 47 of Set 12 | coldwater
# Processing Record 48 of Set 12 | den helder
# Processing Record 49 of Set 12 | amalapuram
# Processing Record 50 of Set 12 | tefe
# Processing Record 1 of Set 13 | saint-augustin
# Processing Record 2 of Set 13 | isiolo
# Processing Record 3 of Set 13 | valparaiso
# Processing Record 4 of Set 13 | shatalovo
# Processing Record 5 of Set 13 | puerto ayora
# Processing Record 6 of Set 13 | sorland
# Processing Record 7 of Set 13 | oliveira do hospital
# Processing Record 8 of Set 13 | cheb
# Processing Record 9 of Set 13 | aksarka
# Processing Record 10 of Set 13 | surt
# Processing Record 11 of Set 13 | tsiroanomandidy
# Processing Record 12 of Set 13 | camocim
# Processing Record 13 of Set 13 | grindavik
# Processing Record 14 of Set 13 | kondagaon
# Processing Record 15 of Set 13 | arica
# Processing Record 16 of Set 13 | abnub
# Processing Record 17 of Set 13 | romanovo
# Processing Record 18 of Set 13 | catumbela
# Processing Record 19 of Set 13 | krasnoarmeysk
# Processing Record 20 of Set 13 | seabra
# Processing Record 21 of Set 13 | sioux lookout
# Processing Record 22 of Set 13 | goma
# Processing Record 23 of Set 13 | wagar
# Processing Record 24 of Set 13 | ust-ishim
# Processing Record 25 of Set 13 | villazon
# Processing Record 26 of Set 13 | bulaevo
# Processing Record 27 of Set 13 | neverkino
# Processing Record 28 of Set 13 | raichur
# Processing Record 29 of Set 13 | kolda
# Processing Record 30 of Set 13 | sinop
# Processing Record 31 of Set 13 | umm lajj
# Processing Record 32 of Set 13 | antofagasta
# Processing Record 33 of Set 13 | sidi ali
# Processing Record 34 of Set 13 | pueblo nuevo
# Processing Record 35 of Set 13 | carbonear
# Processing Record 36 of Set 13 | lieto
# Processing Record 37 of Set 13 | canach
# Processing Record 38 of Set 13 | iracoubo
# Processing Record 39 of Set 13 | domoszlo
# Processing Record 40 of Set 13 | varva
# Processing Record 41 of Set 13 | ati
# Processing Record 42 of Set 13 | pechora
# Processing Record 43 of Set 13 | glossa
# Processing Record 44 of Set 13 | nadezhda
# Processing Record 45 of Set 13 | gomel
# Processing Record 46 of Set 13 | izberbash
# Processing Record 47 of Set 13 | beira
# Processing Record 48 of Set 13 | gueugnon
# Processing Record 49 of Set 13 | zandvoort
# Processing Record 50 of Set 13 | margate
# Processing Record 1 of Set 14 | arbazh
# Processing Record 2 of Set 14 | varhaug
# Processing Record 3 of Set 14 | boyabat
# Processing Record 4 of Set 14 | seoni
# Processing Record 5 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 6 of Set 14 | picsi
# Processing Record 7 of Set 14 | corrales
# Processing Record 8 of Set 14 | inzhavino
# Processing Record 9 of Set 14 | lenki
# City not found. Skipping...
# Processing Record 10 of Set 14 | niteroi
# Processing Record 11 of Set 14 | stanari
# Processing Record 12 of Set 14 | sao borja
# Processing Record 13 of Set 14 | nouadhibou
# Processing Record 14 of Set 14 | damara
# Processing Record 15 of Set 14 | belica
# Processing Record 16 of Set 14 | oistins
# Processing Record 17 of Set 14 | sens
# Processing Record 18 of Set 14 | awjilah
# Processing Record 19 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 20 of Set 14 | port shepstone
# Processing Record 21 of Set 14 | nizwa
# Processing Record 22 of Set 14 | mocuba
# Processing Record 23 of Set 14 | eyl
# Processing Record 24 of Set 14 | pafos
# Processing Record 25 of Set 14 | belize
# Processing Record 26 of Set 14 | aksu
# Processing Record 27 of Set 14 | stornoway
# Processing Record 28 of Set 14 | letterkenny
# Processing Record 29 of Set 14 | mendeleyevsk
# Processing Record 30 of Set 14 | pontivy
# Processing Record 31 of Set 14 | oruro
# Processing Record 32 of Set 14 | salto
# Processing Record 33 of Set 14 | nicoya
# Processing Record 34 of Set 14 | kathmandu
# Processing Record 35 of Set 14 | la palma
# Processing Record 36 of Set 14 | mucurapo
# Processing Record 37 of Set 14 | beloha
# Processing Record 38 of Set 14 | cartagena del chaira
# Processing Record 39 of Set 14 | lamu
# Processing Record 40 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 14 | le creusot
# Processing Record 42 of Set 14 | domokos
# Processing Record 43 of Set 14 | conde
# Processing Record 44 of Set 14 | altay
# Processing Record 45 of Set 14 | barra patuca
# Processing Record 46 of Set 14 | kolyubakino
# Processing Record 47 of Set 14 | petrovsk
# Processing Record 48 of Set 14 | kisangani
# Processing Record 49 of Set 14 | mahajanga
# Processing Record 50 of Set 14 | jacqueville
# Processing Record 1 of Set 15 | shakawe
# Processing Record 2 of Set 15 | mayor pablo lagerenza
# Processing Record 3 of Set 15 | soyo
# Processing Record 4 of Set 15 | zavallya
# Processing Record 5 of Set 15 | paray-le-monial
# Processing Record 6 of Set 15 | kinsale
# Processing Record 7 of Set 15 | raudeberg
# Processing Record 8 of Set 15 | kita
# Processing Record 9 of Set 15 | dwarka
# Processing Record 10 of Set 15 | kattivakkam
# Processing Record 11 of Set 15 | kutum
# Processing Record 12 of Set 15 | crestview
# Processing Record 13 of Set 15 | san matias
# Processing Record 14 of Set 15 | shache
# Processing Record 15 of Set 15 | taltal
# Processing Record 16 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 17 of Set 15 | negele
# City not found. Skipping...
# Processing Record 18 of Set 15 | bedford
# Processing Record 19 of Set 15 | raga
# Processing Record 20 of Set 15 | hollola
# Processing Record 21 of Set 15 | synya
# Processing Record 22 of Set 15 | atar
# Processing Record 23 of Set 15 | lozova
# Processing Record 24 of Set 15 | mut
# Processing Record 25 of Set 15 | ravar
# Processing Record 26 of Set 15 | inirida
# Processing Record 27 of Set 15 | salo
# Processing Record 28 of Set 15 | youghal
# Processing Record 29 of Set 15 | saurimo
# Processing Record 30 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 31 of Set 15 | sao jose da tapera
# Processing Record 32 of Set 15 | interlaken
# Processing Record 33 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 34 of Set 15 | tallahassee
# Processing Record 35 of Set 15 | kapustin yar
# Processing Record 36 of Set 15 | porbandar
# Processing Record 37 of Set 15 | lisakovsk
# Processing Record 38 of Set 15 | istmina
# Processing Record 39 of Set 15 | thinadhoo
# Processing Record 40 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 41 of Set 15 | almaty
# Processing Record 42 of Set 15 | dabakala
# Processing Record 43 of Set 15 | forestville
# Processing Record 44 of Set 15 | kolondieba
# Processing Record 45 of Set 15 | mongu
# Processing Record 46 of Set 15 | narasapur
# Processing Record 47 of Set 15 | saint-andre-les-vergers
# Processing Record 48 of Set 15 | kidal
# Processing Record 49 of Set 15 | ashtabula
# Processing Record 50 of Set 15 | rengo
# Processing Record 1 of Set 16 | male
# Processing Record 2 of Set 16 | hrastnik
# Processing Record 3 of Set 16 | kuznechnoye
# Processing Record 4 of Set 16 | ondangwa
# Processing Record 5 of Set 16 | abha
# Processing Record 6 of Set 16 | ivybridge
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 693

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng Current Description  Max Temp  \
# 0      Kostomuksha      RU  64.5710   30.5767          few clouds     25.97
# 1         Victoria      HK  22.2855  114.1577     overcast clouds     73.45
# 2           Gander      CA  48.9682  -54.5906       broken clouds     48.33
# 3            Serpa      PT  37.9458   -7.5975       broken clouds     78.76
# 4  Arraial Do Cabo      BR -22.9661  -42.0278    scattered clouds     76.86
# 5         Luderitz      NA -26.6481   15.1594           clear sky     60.19
# 6        Busselton      AU -33.6500  115.3333           clear sky     58.03
# 7      Henties Bay      NA -22.1160   14.2845           clear sky     60.31
# 8            Olean      US  42.0776  -78.4297       broken clouds     61.48
# 9     Saint-Pierre      RE -21.3393   55.4781           clear sky     76.68
#
#    Humidity  Cloudiness  Wind Speed
# 0        94          24        2.10
# 1        78          94       18.01
# 2        36          75        4.61
# 3        54          71        8.34
# 4        57          40       14.97
# 5        68           0       22.88
# 6        91          10        6.80
# 7        82           0        9.55
# 8        43          75        6.91
# 9        79           0        5.75

# %%
# New Order of columns
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness",
               "Wind Speed", "Current Description"]
city_data_df = city_data_df[column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kostomuksha      RU  64.5710   30.5767     25.97        94          24
# 1         Victoria      HK  22.2855  114.1577     73.45        78          94
# 2           Gander      CA  48.9682  -54.5906     48.33        36          75
# 3            Serpa      PT  37.9458   -7.5975     78.76        54          71
# 4  Arraial Do Cabo      BR -22.9661  -42.0278     76.86        57          40
# 5         Luderitz      NA -26.6481   15.1594     60.19        68           0
# 6        Busselton      AU -33.6500  115.3333     58.03        91          10
# 7      Henties Bay      NA -22.1160   14.2845     60.31        82           0
# 8            Olean      US  42.0776  -78.4297     61.48        43          75
# 9     Saint-Pierre      RE -21.3393   55.4781     76.68        79           0
#
#    Wind Speed Current Description
# 0        2.10          few clouds
# 1       18.01     overcast clouds
# 2        4.61       broken clouds
# 3        8.34       broken clouds
# 4       14.97    scattered clouds
# 5       22.88           clear sky
# 6        6.80           clear sky
# 7        9.55           clear sky
# 8        6.91       broken clouds
# 9        5.75           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/b2/twj0gkts6fgb95d9zwc0sy1m0000gn/T/ipykernel_91609/1925920037.py in <module>
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
