# %% [markdown]
# # Deliverable 1
#
# Generate a set of 2,000 random latitudes and longitudes, retrive the nearest city,
# and perform an APU call with the OpenWeatherMap. In addition to the weather data,
# retreive the current weather description for each city. Then, create a new DataFrame
# containing the updated weather data.

# %%
# Import the dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy

# %%
# Create a new set of 2000 random latitudes and longitudes
lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -90, high = 90, size = 2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %%
# Create a list to hold the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Build query URL and request your results in Celsius
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5) # Changed to 5 seconds to reduce waiting time

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title()
                          ,"Country": city_country
                          ,"Lat": city_lat
                          ,"Lng": city_lng
                          ,"Current Description": city_description
                          ,"Max Temp": city_max_temp
                          ,"Humidity": city_humidity
                          ,"Cloudiness": city_clouds
                          ,"Wind Speed": city_wind})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | carballo
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | takoradi
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | nadym
# Processing Record 6 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 1 | vardo
# Processing Record 8 of Set 1 | gat
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | xuddur
# Processing Record 11 of Set 1 | los llanos de aridane
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | bambous virieux
# Processing Record 15 of Set 1 | iqaluit
# Processing Record 16 of Set 1 | lyuban
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | ponta delgada
# Processing Record 19 of Set 1 | bucu
# Processing Record 20 of Set 1 | kecel
# Processing Record 21 of Set 1 | longyearbyen
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | black river
# Processing Record 25 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | juru
# Processing Record 29 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 1 | tasiilaq
# Processing Record 31 of Set 1 | marsh harbour
# Processing Record 32 of Set 1 | angoche
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 1 | kandalaksha
# Processing Record 36 of Set 1 | rafaela
# Processing Record 37 of Set 1 | bouar
# Processing Record 38 of Set 1 | baherden
# Processing Record 39 of Set 1 | zabol
# Processing Record 40 of Set 1 | marica
# Processing Record 41 of Set 1 | sari
# Processing Record 42 of Set 1 | kosh-agach
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | sorland
# Processing Record 45 of Set 1 | sistranda
# Processing Record 46 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 1 | muros
# Processing Record 48 of Set 1 | ostrovnoy
# Processing Record 49 of Set 1 | timmins
# Processing Record 50 of Set 1 | rawson
# Processing Record 1 of Set 2 | hamilton
# Processing Record 2 of Set 2 | saint george
# Processing Record 3 of Set 2 | catamarca
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | padang
# Processing Record 6 of Set 2 | brae
# Processing Record 7 of Set 2 | berbera
# Processing Record 8 of Set 2 | oriximina
# Processing Record 9 of Set 2 | ilulissat
# Processing Record 10 of Set 2 | turinsk
# Processing Record 11 of Set 2 | luderitz
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | tevriz
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | souillac
# Processing Record 16 of Set 2 | makat
# Processing Record 17 of Set 2 | awjilah
# Processing Record 18 of Set 2 | vilhena
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | staryy nadym
# Processing Record 21 of Set 2 | areosa
# Processing Record 22 of Set 2 | humaita
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | hofn
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | kangaatsiaq
# Processing Record 27 of Set 2 | waspan
# Processing Record 28 of Set 2 | necochea
# Processing Record 29 of Set 2 | saldanha
# Processing Record 30 of Set 2 | seymour
# Processing Record 31 of Set 2 | bolshoye selo
# Processing Record 32 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 33 of Set 2 | mehamn
# Processing Record 34 of Set 2 | macau
# Processing Record 35 of Set 2 | leshukonskoye
# Processing Record 36 of Set 2 | konevo
# Processing Record 37 of Set 2 | tessalit
# Processing Record 38 of Set 2 | manicore
# Processing Record 39 of Set 2 | kruisfontein
# Processing Record 40 of Set 2 | sao felix do xingu
# Processing Record 41 of Set 2 | olonets
# Processing Record 42 of Set 2 | ji-parana
# City not found. Skipping...
# Processing Record 43 of Set 2 | sayyan
# Processing Record 44 of Set 2 | husavik
# Processing Record 45 of Set 2 | lebu
# Processing Record 46 of Set 2 | lasa
# Processing Record 47 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 2 | boddam
# Processing Record 49 of Set 2 | el balyana
# City not found. Skipping...
# Processing Record 50 of Set 2 | nanortalik
# Processing Record 1 of Set 3 | mangrol
# Processing Record 2 of Set 3 | bria
# Processing Record 3 of Set 3 | bushehr
# Processing Record 4 of Set 3 | bourg-en-bresse
# Processing Record 5 of Set 3 | kaarina
# Processing Record 6 of Set 3 | matelandia
# Processing Record 7 of Set 3 | zhanaozen
# Processing Record 8 of Set 3 | san cristobal
# Processing Record 9 of Set 3 | empa
# City not found. Skipping...
# Processing Record 10 of Set 3 | klaksvik
# Processing Record 11 of Set 3 | seydi
# Processing Record 12 of Set 3 | mumbwa
# Processing Record 13 of Set 3 | fenoarivo
# Processing Record 14 of Set 3 | port-gentil
# Processing Record 15 of Set 3 | busselton
# Processing Record 16 of Set 3 | ponta do sol
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | gradsko
# Processing Record 19 of Set 3 | mitsamiouli
# Processing Record 20 of Set 3 | rundu
# Processing Record 21 of Set 3 | muborak
# Processing Record 22 of Set 3 | tulum
# Processing Record 23 of Set 3 | bollene
# Processing Record 24 of Set 3 | santa vitoria do palmar
# Processing Record 25 of Set 3 | marzuq
# Processing Record 26 of Set 3 | camacha
# Processing Record 27 of Set 3 | touros
# Processing Record 28 of Set 3 | hambantota
# Processing Record 29 of Set 3 | bhander
# Processing Record 30 of Set 3 | monrovia
# Processing Record 31 of Set 3 | dera bugti
# Processing Record 32 of Set 3 | scarborough
# Processing Record 33 of Set 3 | nioro
# Processing Record 34 of Set 3 | rusape
# Processing Record 35 of Set 3 | cordoba
# Processing Record 36 of Set 3 | lagoa
# Processing Record 37 of Set 3 | ivankiv
# Processing Record 38 of Set 3 | cidreira
# Processing Record 39 of Set 3 | marrakesh
# Processing Record 40 of Set 3 | geraldton
# Processing Record 41 of Set 3 | bourges
# Processing Record 42 of Set 3 | namibe
# Processing Record 43 of Set 3 | pulivendla
# Processing Record 44 of Set 3 | winneba
# Processing Record 45 of Set 3 | natal
# Processing Record 46 of Set 3 | sherbakul
# Processing Record 47 of Set 3 | damghan
# Processing Record 48 of Set 3 | george town
# Processing Record 49 of Set 3 | opuwo
# Processing Record 50 of Set 3 | constantine
# Processing Record 1 of Set 4 | chapais
# Processing Record 2 of Set 4 | maceio
# Processing Record 3 of Set 4 | thompson
# Processing Record 4 of Set 4 | adrar
# Processing Record 5 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 6 of Set 4 | kano
# Processing Record 7 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 8 of Set 4 | cockburn town
# Processing Record 9 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 10 of Set 4 | rio das pedras
# Processing Record 11 of Set 4 | la asuncion
# Processing Record 12 of Set 4 | chicama
# Processing Record 13 of Set 4 | zermatt
# Processing Record 14 of Set 4 | torbay
# Processing Record 15 of Set 4 | umm ruwabah
# City not found. Skipping...
# Processing Record 16 of Set 4 | ahmadpur sial
# Processing Record 17 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 4 | paracatu
# Processing Record 19 of Set 4 | sambava
# Processing Record 20 of Set 4 | pandaria
# Processing Record 21 of Set 4 | sept-iles
# Processing Record 22 of Set 4 | senador jose porfirio
# Processing Record 23 of Set 4 | banda aceh
# Processing Record 24 of Set 4 | bethanien
# Processing Record 25 of Set 4 | isiro
# Processing Record 26 of Set 4 | midland
# Processing Record 27 of Set 4 | aquiraz
# Processing Record 28 of Set 4 | neyshabur
# Processing Record 29 of Set 4 | sao domingos
# Processing Record 30 of Set 4 | dunmore east
# Processing Record 31 of Set 4 | narasannapeta
# Processing Record 32 of Set 4 | sabya
# Processing Record 33 of Set 4 | pombia
# Processing Record 34 of Set 4 | mirnyy
# Processing Record 35 of Set 4 | sao filipe
# Processing Record 36 of Set 4 | brekstad
# Processing Record 37 of Set 4 | clyde river
# Processing Record 38 of Set 4 | goderich
# Processing Record 39 of Set 4 | sao bartolomeu de messines
# Processing Record 40 of Set 4 | caravelas
# Processing Record 41 of Set 4 | ancud
# Processing Record 42 of Set 4 | kamenka
# Processing Record 43 of Set 4 | marawi
# Processing Record 44 of Set 4 | elizabeth city
# Processing Record 45 of Set 4 | moose factory
# Processing Record 46 of Set 4 | the valley
# Processing Record 47 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 48 of Set 4 | sao jose da coroa grande
# Processing Record 49 of Set 4 | pimentel
# Processing Record 50 of Set 4 | sinnamary
# Processing Record 1 of Set 5 | saint-francois
# Processing Record 2 of Set 5 | sao gabriel da cachoeira
# Processing Record 3 of Set 5 | comodoro rivadavia
# Processing Record 4 of Set 5 | eusebio
# Processing Record 5 of Set 5 | bud
# Processing Record 6 of Set 5 | hithadhoo
# Processing Record 7 of Set 5 | jamestown
# Processing Record 8 of Set 5 | kapoeta
# Processing Record 9 of Set 5 | murdochville
# Processing Record 10 of Set 5 | harindanga
# Processing Record 11 of Set 5 | eyrarbakki
# Processing Record 12 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 13 of Set 5 | castro
# Processing Record 14 of Set 5 | san ignacio
# Processing Record 15 of Set 5 | reconquista
# Processing Record 16 of Set 5 | oistins
# Processing Record 17 of Set 5 | dudinka
# Processing Record 18 of Set 5 | hit
# Processing Record 19 of Set 5 | moche
# Processing Record 20 of Set 5 | saint-philippe
# Processing Record 21 of Set 5 | baglung
# Processing Record 22 of Set 5 | minab
# Processing Record 23 of Set 5 | muravlenko
# Processing Record 24 of Set 5 | cayenne
# Processing Record 25 of Set 5 | emba
# Processing Record 26 of Set 5 | caarapo
# Processing Record 27 of Set 5 | rio grande
# Processing Record 28 of Set 5 | chiredzi
# Processing Record 29 of Set 5 | raga
# Processing Record 30 of Set 5 | leh
# Processing Record 31 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 5 | inhambane
# Processing Record 33 of Set 5 | narsaq
# Processing Record 34 of Set 5 | achisay
# City not found. Skipping...
# Processing Record 35 of Set 5 | henties bay
# Processing Record 36 of Set 5 | ugoofaaru
# Processing Record 37 of Set 5 | ljungby
# Processing Record 38 of Set 5 | port hawkesbury
# Processing Record 39 of Set 5 | ust-tsilma
# Processing Record 40 of Set 5 | la rioja
# Processing Record 41 of Set 5 | znamenskoye
# Processing Record 42 of Set 5 | rocha
# Processing Record 43 of Set 5 | pangnirtung
# Processing Record 44 of Set 5 | pitkyaranta
# Processing Record 45 of Set 5 | iaciara
# Processing Record 46 of Set 5 | bonthe
# Processing Record 47 of Set 5 | dossor
# Processing Record 48 of Set 5 | inegol
# Processing Record 49 of Set 5 | alanje
# Processing Record 50 of Set 5 | huarmey
# Processing Record 1 of Set 6 | mao
# Processing Record 2 of Set 6 | belyy yar
# Processing Record 3 of Set 6 | paita
# Processing Record 4 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 6 | zambezi
# Processing Record 6 of Set 6 | general roca
# Processing Record 7 of Set 6 | saurimo
# Processing Record 8 of Set 6 | saint-pierre
# Processing Record 9 of Set 6 | quatre cocos
# Processing Record 10 of Set 6 | coihaique
# Processing Record 11 of Set 6 | ust-katav
# Processing Record 12 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 6 | naryan-mar
# Processing Record 14 of Set 6 | sao joao da barra
# Processing Record 15 of Set 6 | puerto colombia
# Processing Record 16 of Set 6 | palaiomanina
# City not found. Skipping...
# Processing Record 17 of Set 6 | korla
# Processing Record 18 of Set 6 | nouadhibou
# Processing Record 19 of Set 6 | jalu
# Processing Record 20 of Set 6 | rio gallegos
# Processing Record 21 of Set 6 | loubomo
# Processing Record 22 of Set 6 | jaora
# Processing Record 23 of Set 6 | grindavik
# Processing Record 24 of Set 6 | oranjemund
# Processing Record 25 of Set 6 | prykolotne
# Processing Record 26 of Set 6 | neftcala
# Processing Record 27 of Set 6 | amarwara
# Processing Record 28 of Set 6 | mabaruma
# Processing Record 29 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 6 | anzio
# Processing Record 31 of Set 6 | bako
# Processing Record 32 of Set 6 | olafsvik
# Processing Record 33 of Set 6 | arlit
# Processing Record 34 of Set 6 | paamiut
# Processing Record 35 of Set 6 | soyo
# Processing Record 36 of Set 6 | novyy urengoy
# Processing Record 37 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 38 of Set 6 | chato
# Processing Record 39 of Set 6 | muriti
# Processing Record 40 of Set 6 | margate
# Processing Record 41 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 42 of Set 6 | warrington
# Processing Record 43 of Set 6 | minsk
# Processing Record 44 of Set 6 | phalombe
# Processing Record 45 of Set 6 | villefontaine
# Processing Record 46 of Set 6 | anloga
# Processing Record 47 of Set 6 | adre
# Processing Record 48 of Set 6 | carutapera
# Processing Record 49 of Set 6 | podor
# Processing Record 50 of Set 6 | jawhar
# Processing Record 1 of Set 7 | monze
# Processing Record 2 of Set 7 | norton shores
# Processing Record 3 of Set 7 | beloha
# Processing Record 4 of Set 7 | stornoway
# Processing Record 5 of Set 7 | zaykovo
# Processing Record 6 of Set 7 | clarence town
# Processing Record 7 of Set 7 | santa cruz
# Processing Record 8 of Set 7 | mandera
# Processing Record 9 of Set 7 | sharjah
# Processing Record 10 of Set 7 | vila franca do campo
# Processing Record 11 of Set 7 | honningsvag
# Processing Record 12 of Set 7 | skjervoy
# Processing Record 13 of Set 7 | neman
# Processing Record 14 of Set 7 | matara
# Processing Record 15 of Set 7 | benjamin aceval
# Processing Record 16 of Set 7 | bay roberts
# Processing Record 17 of Set 7 | raudeberg
# Processing Record 18 of Set 7 | turinskaya sloboda
# Processing Record 19 of Set 7 | tutoia
# Processing Record 20 of Set 7 | malaryta
# Processing Record 21 of Set 7 | kudahuvadhoo
# Processing Record 22 of Set 7 | abu samrah
# Processing Record 23 of Set 7 | peto
# Processing Record 24 of Set 7 | ila
# Processing Record 25 of Set 7 | doha
# Processing Record 26 of Set 7 | cap malheureux
# Processing Record 27 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 28 of Set 7 | walvis bay
# Processing Record 29 of Set 7 | pedro ii
# Processing Record 30 of Set 7 | krasnousolskiy
# City not found. Skipping...
# Processing Record 31 of Set 7 | sona
# Processing Record 32 of Set 7 | sainte-suzanne
# Processing Record 33 of Set 7 | funadhoo
# Processing Record 34 of Set 7 | nalut
# Processing Record 35 of Set 7 | laguna
# Processing Record 36 of Set 7 | maniitsoq
# Processing Record 37 of Set 7 | fecamp
# Processing Record 38 of Set 7 | wladyslawowo
# Processing Record 39 of Set 7 | domoni
# Processing Record 40 of Set 7 | teguldet
# Processing Record 41 of Set 7 | talnakh
# Processing Record 42 of Set 7 | barra patuca
# Processing Record 43 of Set 7 | jijiga
# Processing Record 44 of Set 7 | iquique
# Processing Record 45 of Set 7 | svetlyy
# Processing Record 46 of Set 7 | sao joao de pirabas
# Processing Record 47 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 48 of Set 7 | upernavik
# Processing Record 49 of Set 7 | saint-augustin
# Processing Record 50 of Set 7 | bystrzyca klodzka
# Processing Record 1 of Set 8 | kalevala
# Processing Record 2 of Set 8 | melukote
# Processing Record 3 of Set 8 | nevsehir
# Processing Record 4 of Set 8 | praia da vitoria
# Processing Record 5 of Set 8 | baghdad
# Processing Record 6 of Set 8 | urucara
# Processing Record 7 of Set 8 | coquimbo
# Processing Record 8 of Set 8 | xaxim
# Processing Record 9 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 10 of Set 8 | marsa matruh
# Processing Record 11 of Set 8 | pidhorodna
# Processing Record 12 of Set 8 | sardarshahr
# Processing Record 13 of Set 8 | siteki
# Processing Record 14 of Set 8 | itororo
# Processing Record 15 of Set 8 | bridlington
# Processing Record 16 of Set 8 | bomet
# Processing Record 17 of Set 8 | berlevag
# Processing Record 18 of Set 8 | patnos
# Processing Record 19 of Set 8 | channel-port aux basques
# Processing Record 20 of Set 8 | krumovgrad
# Processing Record 21 of Set 8 | severnoye
# Processing Record 22 of Set 8 | acarau
# Processing Record 23 of Set 8 | gao
# Processing Record 24 of Set 8 | beckley
# Processing Record 25 of Set 8 | iracoubo
# Processing Record 26 of Set 8 | arrifes
# Processing Record 27 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 28 of Set 8 | salalah
# Processing Record 29 of Set 8 | santa isabel do rio negro
# Processing Record 30 of Set 8 | hukuntsi
# Processing Record 31 of Set 8 | meybod
# Processing Record 32 of Set 8 | methoni
# Processing Record 33 of Set 8 | marapanim
# Processing Record 34 of Set 8 | carnarvon
# Processing Record 35 of Set 8 | wad madani
# Processing Record 36 of Set 8 | mahebourg
# Processing Record 37 of Set 8 | aquidauana
# Processing Record 38 of Set 8 | galdar
# Processing Record 39 of Set 8 | kajaani
# Processing Record 40 of Set 8 | troy
# Processing Record 41 of Set 8 | albany
# Processing Record 42 of Set 8 | bandarbeyla
# Processing Record 43 of Set 8 | ginir
# Processing Record 44 of Set 8 | itupiranga
# Processing Record 45 of Set 8 | grand-santi
# Processing Record 46 of Set 8 | santiago del estero
# Processing Record 47 of Set 8 | edd
# Processing Record 48 of Set 8 | umm lajj
# Processing Record 49 of Set 8 | khachrod
# Processing Record 50 of Set 8 | molochnoye
# Processing Record 1 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 9 | mitu
# Processing Record 3 of Set 9 | akureyri
# Processing Record 4 of Set 9 | buraydah
# Processing Record 5 of Set 9 | itarema
# Processing Record 6 of Set 9 | budogoshch
# Processing Record 7 of Set 9 | vestmannaeyjar
# Processing Record 8 of Set 9 | bakel
# Processing Record 9 of Set 9 | chegem
# Processing Record 10 of Set 9 | omboue
# Processing Record 11 of Set 9 | dombarovskiy
# Processing Record 12 of Set 9 | aleysk
# Processing Record 13 of Set 9 | la palma
# Processing Record 14 of Set 9 | luanda
# Processing Record 15 of Set 9 | mme
# City not found. Skipping...
# Processing Record 16 of Set 9 | nebbi
# Processing Record 17 of Set 9 | lyndon
# Processing Record 18 of Set 9 | lucapa
# Processing Record 19 of Set 9 | libreville
# Processing Record 20 of Set 9 | bonavista
# Processing Record 21 of Set 9 | kentau
# Processing Record 22 of Set 9 | abay
# Processing Record 23 of Set 9 | am timan
# Processing Record 24 of Set 9 | morondava
# Processing Record 25 of Set 9 | jinka
# Processing Record 26 of Set 9 | sankheda
# Processing Record 27 of Set 9 | tazovskiy
# Processing Record 28 of Set 9 | codrington
# Processing Record 29 of Set 9 | taltal
# Processing Record 30 of Set 9 | abong mbang
# Processing Record 31 of Set 9 | yar-sale
# Processing Record 32 of Set 9 | kavaratti
# Processing Record 33 of Set 9 | zaranj
# Processing Record 34 of Set 9 | novaya ladoga
# Processing Record 35 of Set 9 | presidencia roque saenz pena
# Processing Record 36 of Set 9 | chiriguana
# Processing Record 37 of Set 9 | senneterre
# Processing Record 38 of Set 9 | conceicao do araguaia
# Processing Record 39 of Set 9 | anoyia
# City not found. Skipping...
# Processing Record 40 of Set 9 | kashi
# Processing Record 41 of Set 9 | sirjan
# Processing Record 42 of Set 9 | chail
# Processing Record 43 of Set 9 | rurrenabaque
# Processing Record 44 of Set 9 | dwarka
# Processing Record 45 of Set 9 | mundybash
# Processing Record 46 of Set 9 | grand gaube
# Processing Record 47 of Set 9 | wagar
# Processing Record 48 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 9 | lagos
# Processing Record 1 of Set 10 | sehithwa
# Processing Record 2 of Set 10 | mongo
# Processing Record 3 of Set 10 | kedrovyy
# Processing Record 4 of Set 10 | mogadishu
# Processing Record 5 of Set 10 | antalaha
# Processing Record 6 of Set 10 | yambio
# Processing Record 7 of Set 10 | vestmanna
# Processing Record 8 of Set 10 | senekal
# Processing Record 9 of Set 10 | malakal
# Processing Record 10 of Set 10 | breyten
# Processing Record 11 of Set 10 | pudozh
# Processing Record 12 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 13 of Set 10 | suez
# Processing Record 14 of Set 10 | constitucion
# Processing Record 15 of Set 10 | tibati
# Processing Record 16 of Set 10 | bagno a ripoli
# Processing Record 17 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 18 of Set 10 | chabahar
# Processing Record 19 of Set 10 | diamantina
# Processing Record 20 of Set 10 | atar
# Processing Record 21 of Set 10 | roald
# Processing Record 22 of Set 10 | san juan
# Processing Record 23 of Set 10 | kang
# Processing Record 24 of Set 10 | chichimila
# Processing Record 25 of Set 10 | maarianhamina
# Processing Record 26 of Set 10 | ostersund
# Processing Record 27 of Set 10 | riviere-au-renard
# Processing Record 28 of Set 10 | kroderen
# City not found. Skipping...
# Processing Record 29 of Set 10 | saint anthony
# Processing Record 30 of Set 10 | lupiro
# Processing Record 31 of Set 10 | saint-joseph
# Processing Record 32 of Set 10 | liwale
# Processing Record 33 of Set 10 | kasese
# Processing Record 34 of Set 10 | sargodha
# Processing Record 35 of Set 10 | nuuk
# Processing Record 36 of Set 10 | oudtshoorn
# Processing Record 37 of Set 10 | shihezi
# Processing Record 38 of Set 10 | vasylivka
# Processing Record 39 of Set 10 | sur
# Processing Record 40 of Set 10 | bukama
# Processing Record 41 of Set 10 | alta floresta
# Processing Record 42 of Set 10 | khorramshahr
# Processing Record 43 of Set 10 | mana
# Processing Record 44 of Set 10 | marmaris
# Processing Record 45 of Set 10 | vannes
# Processing Record 46 of Set 10 | araouane
# Processing Record 47 of Set 10 | maracacume
# Processing Record 48 of Set 10 | plettenberg bay
# Processing Record 49 of Set 10 | agaro
# Processing Record 50 of Set 10 | brigantine
# Processing Record 1 of Set 11 | santa maria
# Processing Record 2 of Set 11 | culebra
# Processing Record 3 of Set 11 | chimbote
# Processing Record 4 of Set 11 | kilifi
# Processing Record 5 of Set 11 | laurel
# Processing Record 6 of Set 11 | rudbar
# Processing Record 7 of Set 11 | axim
# Processing Record 8 of Set 11 | high rock
# Processing Record 9 of Set 11 | aksu
# Processing Record 10 of Set 11 | la cruz
# Processing Record 11 of Set 11 | dvinskoy
# Processing Record 12 of Set 11 | dhidhdhoo
# Processing Record 13 of Set 11 | mamlyutka
# Processing Record 14 of Set 11 | kirkland lake
# Processing Record 15 of Set 11 | dabat
# Processing Record 16 of Set 11 | santa cecilia
# Processing Record 17 of Set 11 | keti bandar
# Processing Record 18 of Set 11 | berekum
# Processing Record 19 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 20 of Set 11 | belmonte
# Processing Record 21 of Set 11 | pauini
# Processing Record 22 of Set 11 | dasoguz
# Processing Record 23 of Set 11 | kutum
# Processing Record 24 of Set 11 | sao simao
# Processing Record 25 of Set 11 | kirovskiy
# Processing Record 26 of Set 11 | marsaxlokk
# Processing Record 27 of Set 11 | diamantino
# Processing Record 28 of Set 11 | olavarria
# Processing Record 29 of Set 11 | polyarnyy
# Processing Record 30 of Set 11 | duz
# City not found. Skipping...
# Processing Record 31 of Set 11 | eyl
# Processing Record 32 of Set 11 | formosa
# Processing Record 33 of Set 11 | svarychiv
# Processing Record 34 of Set 11 | nantucket
# Processing Record 35 of Set 11 | xghajra
# City not found. Skipping...
# Processing Record 36 of Set 11 | susangerd
# Processing Record 37 of Set 11 | novyy svit
# Processing Record 38 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 11 | santa rosa
# Processing Record 40 of Set 11 | havoysund
# Processing Record 41 of Set 11 | notre-dame-du-lac
# Processing Record 42 of Set 11 | gayny
# Processing Record 43 of Set 11 | kaniama
# Processing Record 44 of Set 11 | ponta pora
# Processing Record 45 of Set 11 | agirish
# Processing Record 46 of Set 11 | stykkisholmur
# Processing Record 47 of Set 11 | puerto berrio
# Processing Record 48 of Set 11 | benghazi
# Processing Record 49 of Set 11 | jumla
# Processing Record 50 of Set 11 | macae
# Processing Record 1 of Set 12 | qunduz
# Processing Record 2 of Set 12 | pisco
# Processing Record 3 of Set 12 | wattegama
# Processing Record 4 of Set 12 | mirabad
# Processing Record 5 of Set 12 | puerto del rosario
# Processing Record 6 of Set 12 | ayabaca
# Processing Record 7 of Set 12 | saquarema
# Processing Record 8 of Set 12 | antofagasta
# Processing Record 9 of Set 12 | stokmarknes
# Processing Record 10 of Set 12 | kumluca
# Processing Record 11 of Set 12 | kiruna
# Processing Record 12 of Set 12 | kattivakkam
# Processing Record 13 of Set 12 | goure
# Processing Record 14 of Set 12 | zhob
# Processing Record 15 of Set 12 | vila velha
# Processing Record 16 of Set 12 | saint-pacome
# City not found. Skipping...
# Processing Record 17 of Set 12 | surt
# Processing Record 18 of Set 12 | bama
# Processing Record 19 of Set 12 | kincardine
# Processing Record 20 of Set 12 | skage
# City not found. Skipping...
# Processing Record 21 of Set 12 | langres
# Processing Record 22 of Set 12 | uchaly
# Processing Record 23 of Set 12 | verkhnyaya inta
# Processing Record 24 of Set 12 | oranjestad
# Processing Record 25 of Set 12 | hauterive
# Processing Record 26 of Set 12 | umtata
# Processing Record 27 of Set 12 | sebinkarahisar
# Processing Record 28 of Set 12 | gravdal
# Processing Record 29 of Set 12 | punta de piedra
# Processing Record 30 of Set 12 | mpanda
# Processing Record 31 of Set 12 | lerwick
# Processing Record 32 of Set 12 | qaqortoq
# Processing Record 33 of Set 12 | lakhdenpokhya
# Processing Record 34 of Set 12 | dingle
# Processing Record 35 of Set 12 | havre-saint-pierre
# Processing Record 36 of Set 12 | sawakin
# Processing Record 37 of Set 12 | midyat
# Processing Record 38 of Set 12 | campbellton
# Processing Record 39 of Set 12 | isetskoye
# Processing Record 40 of Set 12 | dakar
# Processing Record 41 of Set 12 | santa fe
# Processing Record 42 of Set 12 | birao
# Processing Record 43 of Set 12 | rozivka
# Processing Record 44 of Set 12 | asheville
# Processing Record 45 of Set 12 | kohtla-nomme
# Processing Record 46 of Set 12 | inskoy
# Processing Record 47 of Set 12 | verkhniy mamon
# Processing Record 48 of Set 12 | bolshaya sosnova
# Processing Record 49 of Set 12 | ercis
# Processing Record 50 of Set 12 | copiapo
# Processing Record 1 of Set 13 | blind river
# Processing Record 2 of Set 13 | buchanan
# Processing Record 3 of Set 13 | colmenar viejo
# Processing Record 4 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 13 | tabou
# Processing Record 6 of Set 13 | pavilosta
# Processing Record 7 of Set 13 | bodden town
# Processing Record 8 of Set 13 | barao de cocais
# Processing Record 9 of Set 13 | port blair
# Processing Record 10 of Set 13 | ladario
# Processing Record 11 of Set 13 | alexandria
# Processing Record 12 of Set 13 | maldonado
# Processing Record 13 of Set 13 | ruhengeri
# Processing Record 14 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 13 | progreso
# Processing Record 16 of Set 13 | boden
# Processing Record 17 of Set 13 | la serena
# Processing Record 18 of Set 13 | basse
# Processing Record 19 of Set 13 | dzerzhinsk
# Processing Record 20 of Set 13 | natitingou
# Processing Record 21 of Set 13 | urla
# Processing Record 22 of Set 13 | korem
# Processing Record 23 of Set 13 | asuncion
# Processing Record 24 of Set 13 | kankaanpaa
# Processing Record 25 of Set 13 | baltoji voke
# Processing Record 26 of Set 13 | havelock
# Processing Record 27 of Set 13 | thinadhoo
# Processing Record 28 of Set 13 | coxim
# Processing Record 29 of Set 13 | ereymentau
# Processing Record 30 of Set 13 | arroio grande
# Processing Record 31 of Set 13 | gulshat
# City not found. Skipping...
# Processing Record 32 of Set 13 | yarada
# Processing Record 33 of Set 13 | nouakchott
# Processing Record 34 of Set 13 | san ramon
# Processing Record 35 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 36 of Set 13 | gondar
# Processing Record 37 of Set 13 | virginia beach
# Processing Record 38 of Set 13 | avon
# Processing Record 39 of Set 13 | sainte-anne-des-monts
# Processing Record 40 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 13 | misratah
# Processing Record 42 of Set 13 | tahoua
# Processing Record 43 of Set 13 | haradok
# Processing Record 44 of Set 13 | fomboni
# Processing Record 45 of Set 13 | kinanah
# City not found. Skipping...
# Processing Record 46 of Set 13 | burica
# City not found. Skipping...
# Processing Record 47 of Set 13 | oum hadjer
# Processing Record 48 of Set 13 | corralillo
# Processing Record 49 of Set 13 | asyut
# Processing Record 50 of Set 13 | obo
# Processing Record 1 of Set 14 | lodwar
# Processing Record 2 of Set 14 | kanniyakumari
# Processing Record 3 of Set 14 | harper
# Processing Record 4 of Set 14 | ewo
# Processing Record 5 of Set 14 | keshabpur
# Processing Record 6 of Set 14 | pozo colorado
# Processing Record 7 of Set 14 | gurupi
# Processing Record 8 of Set 14 | bell ville
# Processing Record 9 of Set 14 | bubaque
# Processing Record 10 of Set 14 | odienne
# Processing Record 11 of Set 14 | benicarlo
# Processing Record 12 of Set 14 | cervo
# Processing Record 13 of Set 14 | lokosovo
# Processing Record 14 of Set 14 | nizwa
# Processing Record 15 of Set 14 | sidi ali
# Processing Record 16 of Set 14 | manzil jamil
# City not found. Skipping...
# Processing Record 17 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 18 of Set 14 | batamshinskiy
# Processing Record 19 of Set 14 | san andres
# Processing Record 20 of Set 14 | riyadh
# Processing Record 21 of Set 14 | tamandare
# Processing Record 22 of Set 14 | wexford
# Processing Record 23 of Set 14 | armacao de pera
# Processing Record 24 of Set 14 | kochki
# Processing Record 25 of Set 14 | viedma
# Processing Record 26 of Set 14 | dzaoudzi
# Processing Record 27 of Set 14 | kings point
# Processing Record 28 of Set 14 | oakham
# Processing Record 29 of Set 14 | olinda
# Processing Record 30 of Set 14 | maniwaki
# Processing Record 31 of Set 14 | aquitania
# Processing Record 32 of Set 14 | kerman
# Processing Record 33 of Set 14 | kalyazin
# Processing Record 34 of Set 14 | cornwall
# Processing Record 35 of Set 14 | acari
# Processing Record 36 of Set 14 | bonito
# Processing Record 37 of Set 14 | iquitos
# Processing Record 38 of Set 14 | skrunda
# Processing Record 39 of Set 14 | kalmunai
# Processing Record 40 of Set 14 | odweyne
# Processing Record 41 of Set 14 | praia
# Processing Record 42 of Set 14 | viljoenskroon
# Processing Record 43 of Set 14 | novoseleznevo
# Processing Record 44 of Set 14 | eufaula
# Processing Record 45 of Set 14 | bobo dioulasso
# Processing Record 46 of Set 14 | kpandae
# Processing Record 47 of Set 14 | buenos aires
# Processing Record 48 of Set 14 | bilma
# Processing Record 49 of Set 14 | monte patria
# Processing Record 50 of Set 14 | laukaa
# Processing Record 1 of Set 15 | ganta
# Processing Record 2 of Set 15 | jacareacanga
# Processing Record 3 of Set 15 | koungou
# Processing Record 4 of Set 15 | ilhabela
# Processing Record 5 of Set 15 | aksehir
# Processing Record 6 of Set 15 | turukhansk
# Processing Record 7 of Set 15 | timizart
# Processing Record 8 of Set 15 | taoudenni
# Processing Record 9 of Set 15 | kedougou
# Processing Record 10 of Set 15 | bathsheba
# Processing Record 11 of Set 15 | sandnessjoen
# Processing Record 12 of Set 15 | tabory
# Processing Record 13 of Set 15 | tarrafal
# Processing Record 14 of Set 15 | trinidad
# Processing Record 15 of Set 15 | donja dubica
# Processing Record 16 of Set 15 | bafoulabe
# Processing Record 17 of Set 15 | lowestoft
# Processing Record 18 of Set 15 | picton
# Processing Record 19 of Set 15 | niteroi
# Processing Record 20 of Set 15 | maxixe
# Processing Record 21 of Set 15 | biltine
# Processing Record 22 of Set 15 | belem
# Processing Record 23 of Set 15 | atbasar
# Processing Record 24 of Set 15 | arona
# Processing Record 25 of Set 15 | conceicao da barra
# Processing Record 26 of Set 15 | luzino
# Processing Record 27 of Set 15 | kabalo
# Processing Record 28 of Set 15 | washington
# Processing Record 29 of Set 15 | carupano
# Processing Record 30 of Set 15 | rorvik
# Processing Record 31 of Set 15 | rolim de moura
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 674

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng Current Description  \
# 0               Carballo      ES  43.2130   -8.6910           clear sky
# 1               Takoradi      GH   4.8845   -1.7554       broken clouds
# 2                 Dikson      RU  73.5069   80.5464          light snow
# 3                  Nadym      RU  65.5333   72.5167     overcast clouds
# 4                  Vardo      NO  70.3705   31.1107          light snow
# 5                    Gat      IL  31.6100   34.7642     overcast clouds
# 6             Georgetown      MY   5.4112  100.3354          few clouds
# 7                 Xuddur      SO   4.1213   43.8894     overcast clouds
# 8  Los Llanos De Aridane      ES  28.6585  -17.9182           clear sky
# 9                Ushuaia      AR -54.8000  -68.3000    scattered clouds
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     61.43        93           5        2.10
# 1     80.58        80          64       10.29
# 2     18.37        95         100       10.89
# 3     26.13        92         100        2.84
# 4     32.11        97         100       10.49
# 5     66.40        67         100        6.33
# 6     80.53        94          20        0.00
# 7     83.55        52         100       11.18
# 8     66.13        79           0       16.11
# 9     49.66        71          40       19.57

# %%
# New Order of columns
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness",
               "Wind Speed", "Current Description"]
city_data_df = city_data_df[column_order]
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Carballo      ES  43.2130   -8.6910     61.43        93
# 1               Takoradi      GH   4.8845   -1.7554     80.58        80
# 2                 Dikson      RU  73.5069   80.5464     18.37        95
# 3                  Nadym      RU  65.5333   72.5167     26.13        92
# 4                  Vardo      NO  70.3705   31.1107     32.11        97
# 5                    Gat      IL  31.6100   34.7642     66.40        67
# 6             Georgetown      MY   5.4112  100.3354     80.53        94
# 7                 Xuddur      SO   4.1213   43.8894     83.55        52
# 8  Los Llanos De Aridane      ES  28.6585  -17.9182     66.13        79
# 9                Ushuaia      AR -54.8000  -68.3000     49.66        71
#
#    Cloudiness  Wind Speed Current Description
# 0           5        2.10           clear sky
# 1          64       10.29       broken clouds
# 2         100       10.89          light snow
# 3         100        2.84     overcast clouds
# 4         100       10.49          light snow
# 5         100        6.33     overcast clouds
# 6          20        0.00          few clouds
# 7         100       11.18     overcast clouds
# 8           0       16.11           clear sky
# 9          40       19.57    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
